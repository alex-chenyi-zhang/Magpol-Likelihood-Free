# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.loadtxt("MC_data.txt",delimiter=',')

# %%
data
# Out:
# array([[-3.00000000e+00,  7.00000000e-02,  3.33325000e+03],
#        [-7.50000000e+01,  5.00000000e-02,  3.26296000e+03],
#        [-3.90000000e+01, -4.00000000e-02,  2.04710635e+03],
#        ...,
#        [-5.80000000e+01,  6.00000000e-02,  1.84155500e+02],
#        [-6.50000000e+01,  1.40000000e-01,  1.67486650e+02],
#        [-8.60000000e+01, -9.00000000e-02,  1.66826350e+02]])

# %%
data[:,0]
# Out:
# array([ -3., -75., -39., ..., -58., -65., -86.])

# %%
plt.plot(data[:,0])

# %%
plt.plot(data[:,1])

# %%
plt.plot(data[200:,2])
