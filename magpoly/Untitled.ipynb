# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.loadtxt("MC_data.txt",delimiter=',')

# %%
data
# Out:
# array([[ 1.30000000e+01, -5.20000000e-02,  2.08332500e+04],
#        [-1.75000000e+02, -8.00000000e-03,  2.08332500e+04],
#        [-1.83000000e+02, -2.00000000e-02,  1.30807598e+04],
#        ...,
#        [-2.98000000e+02,  1.40000000e-01,  2.20783536e+02],
#        [-2.70000000e+02,  8.40000000e-02,  2.20783536e+02],
#        [-2.84000000e+02, -2.40000000e-02,  2.20783536e+02]])

# %%
data[:,0]
# Out:
# array([  13., -175., -183., ..., -298., -270., -284.])

# %%
plt.plot(data[:,0])

# %%
plt.plot(data[:,1])

# %%
plt.plot(data[2:,2])
